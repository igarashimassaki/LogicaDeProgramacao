# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/LogicaDeProgramacao/blob/main/LP03_Fluxogramas_Vari%C3%A1veis_Tipos_de_Dados_e_Operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Neste capítulo abordaremos:**
# > - **Introdução à Linguagem de Programação Python**
# > - **Conceitos Introdutórios de Python:**
#   - Identificadores: Variável e Operadores
#   - Operadores Aritméticos e Relacionais
#   - Entendendo o que é sistema: ENTRADA, PROCESSAMENTO E SAÍDA
#   - Variável tipo inteira e tipo real

# %% [markdown]
# # **01 - Introdução à Linguagem de Programação**

# %% [markdown]
# <div align="justify">
#
# > Conforme definido, um software ou programa é um conjunto de instruções que informam ao computador o que fazer. Geralmente com o objetivo de realizar uma tarefa para facilitar a vida do usuário.
# Um programa de computador contém um **algoritmo** (ou seja, um **conjunto das regras e procedimentos lógicos perfeitamente definidos que levam à solução de um problema em um número finito de etapas**) e que pode ser uma representação de um sistema real, logo, um modelo que representa um sistema e a forma como ocorrem as modificações no mesmo.
#
# Nas últimas aulas aprendemos sobre algoritmo e suas formas de representação, inclusive sobre a função do algoritmos de representar uma solução para um problema no mundo real escrito em linguagem que o computador compreende. Com esse mesmo pensamento, podemos entender que cada item tratado nesse problema pode ser representado por uma **variável.**
#
# #**VARIÁVEIS**
#
#
# > Variável é tudo que está **sujeito a variações**, que **é incerto, instável ou inconstante.** Quando se fala de **computadores**, é preciso ter em mente que o volume de dados a serem tratados é grande e diversificado. Dessa forma, os **dados a serem processados são bastante variáveis**.
#
#
# **As variáveis são elementos básicos na programação, pois são aquelas que armazenam os dados contidos no algoritmo. Cada dado pode ser de um tipo diferente e, por isso é preciso mostrar ao algoritmo, logo no início, o que esperar armazenar.**
# >
#
# **Todo dado a ser armazenado na memória de um computador deve ser previamente identificado segundo seu tipo,** ou seja, primeiramente é necessário saber o tipo do dado para depois fazer seu armazenamento adequado. **Armazenado o dado, ele pode ser utilizado e processado a qualquer momento.**
#
#
# > **Regras para identificadores:**
# >
# > Um identificador pode ter até 32 caracteres de comprimento.
# > - O 1º caractere deve ser uma letra do alfabeto.
# > - Os demais caracteres podem ser letras, números ou sinal underscore (_)
# > - Não usar sinais de pontuação, caracteres acentuados, cedilha (ç) ou espaço em branco.
# >
# > Exemplos de identificadores: **Nome, Nome_Cliente, Nome_Completo, Data, Data_Emissao, Mensagem, Aviso, 1aSemana, Endereco, a, b, c, ..., X, Y, Z**.
#
# **Não esqueça:**
#
# > Uma variável representa um contêiner ou espaço na memória física ou virtual de um computador, onde diferentes tipos de dados (valores) são armazenados durante a execução de um programa. A cada variável é atribuído um nome descritivo ou identificador que se refere ao valor salvo.
# >
# >Elas são importantes para o funcionamento de programas e aplicações que lidam com cálculos, condições, repetições e qualquer outro dado mutável durante o seu funcionamento.
#
# </div>

# %% [markdown]
# ### Pode-se dizer que **você certamente irá lidar com variáveis na maior parte do seu tempo como profissional de programação**, mas as variáveis não costumam vir sozinhas; elas costumam aparecer com **operadores aritméticos e relacionais**, principalmente quando o programa tem a função de processar algum cálculo específico ou algum sinal de entrada para tomar uma determinada decisão.

# %% [markdown]
# ![LP03 - Operadores Aritmeticos.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![LP03 - Operadores Relacionais.png](data:image/png;base64,...)

# %% [markdown]
# As operações com os operadores aritméticos básicos podem ser feitas de forma a armazenar os cálculos realizados primeiramente em variáveis e em seguida exibí-los. Isto é um procedimento muito comum na computação; já que as variáveis tem seus valores armazenados em posições da memória RAM do computador.
#
# ##***Mas antes de sairmos processando e fazendo uso de variáveis e operadores, é preciso fazer uma pausa para responder duas perguntas:***
# #**O QUE É UM SISTEMA? O COMPUTADOR É UM SISTEMA?**

# %% [markdown]
# ![LP03 - Introdução_O computador é um sistema.png](data:image/png;base64,...)
#
#
# ![LP03 - Introdução_O Sistema processando um programa.png](data:image/png;base64,...)
#
# </div>

# %%
# POSSO ARMAZENAR VALORES E CÁLCULOS EM VARIAVEIS E DEPOIS EXIBÍ-LOS (Isto se faz com muita frequência!)
# Exemplo 01) Crie um código em linguagem Python p/ Solicitar 2 valores a e b e em seguida calcular e exibir o resultado.
#Nas linhas a seguir, você verá o código Python junto a comentários explicativos que iniciam com #

#ENTRADAS DO PROGRAMA
# Imprimir("Digite a: ") e ler_e_guardar(a)
a = input("Digite a:")
# Imprimir("Digite b: ") e ler_e_guardar(b)
b = input("Digite b:")

#PROCESSAMENTO
# Processar soma = real(a) + real(b)
soma = float(a) + float(b)

#SAÍDA NA TELA
#Imprimir(soma)
print(soma)

# %% [markdown]
# ### A seguir, apenas o código anterior python sem os comentários:

# %%
a = input("Digite a:")
b = input("Digite b:")
soma = float(a) + float(b)
print(soma)

# %% [markdown]
# #**Exemplo 02)** Crie um código de programa em linguagem Python para Solicitar dois valores a e b e em seguida calcular e exibir o resultado de:
# *   Soma
# *   Subtração
# *   Multiplicação
# *   Divisão
# *   Divisão Inteira
# *   Potência
# *   Resto

# %%
#EXEMPLO 01
#ENTRADAS DO PROGRAMA
a = input("Digite a:")
b = input("Digite b:")
#PROCESSAMENTO
soma = int(a) + int(b)
subtracao = int(a) - int(b)
multiplicacao = int(a) * int(b)
divisao = int(a)/int(b)
DivisaoInteira = int(a)//int(b)
potencia = int(a)**int(b)
resto = int(a)%int(b)
#SAÍDA NA TELA
print("Soma = ", str(soma))
print("Subtração = ", str(subtracao))
print("Multiplicação = ", str(multiplicacao))
print("Divisão = ", str(divisao))
print("Divisão Inteira = ", str(DivisaoInteira))
print("a elevado a b = ", str(potencia))
print("Resto da divisao de a por b = ", str(resto))

# %% [markdown]
# #**Exemplo 03**
# Crie um código de programa em linguagem Python para Solicitar dois valores X e Y e em seguida exibir demonstração dos operadores relacionais:

# %% [markdown]
# ####**Operador Menor que**

# %%
#Operador Menor que

#ENTRADAS DO PROGRAMA
X = float(input("Digite X:"))
Y = float(input("Digite Y:"))
#PROCESSAMENTO
if(X<Y):
#SAÍDA
  print("X é menor que Y.")

# %% [markdown]
# ####**Operador Maior que**

# %%
#Operador Maior que

#ENTRADAS DO PROGRAMA
X = float(input("Digite X:"))
Y = float(input("Digite Y:"))
#PROCESSAMENTO
if(X>Y):
#SAÍDA
  print("X é Maior que Y.")

# %% [markdown]
# ####**Operador IGUAL**

# %%
#Operador IGUAL

#ENTRADAS DO PROGRAMA
X = float(input("Digite X:"))
Y = float(input("Digite Y:"))
#PROCESSAMENTO
if(X==Y):
#SAÍDA
  print("X é IGUAL a Y.")

# %% [markdown]
# ####**Operador de ATRIBUIÇÃO**

# %%
#Operador de ATRIBUIÇÃO
X=2
print("X=", X)

# %% [markdown]
# ####**Operador DIFERENTE**

# %%
#Operador Diferente

#ENTRADAS DO PROGRAMA
X = float(input("Digite X:"))
Y = float(input("Digite Y:"))
#PROCESSAMENTO
if(X!=Y):
#SAÍDA
  print("X é DIFERENTE de Y.")

# %% [markdown]
# ####**Operador Menor ou Igual a

# %%
#Operador Menor ou Igual a

#ENTRADAS DO PROGRAMA
X = float(input("Digite X:"))
Y = float(input("Digite Y:"))
#PROCESSAMENTO
if(X<=Y):
#SAÍDA
  print("X é menor ou Igual a Y.")

# %% [markdown]
# ####**Operador Maior ou Igual a

# %%
#Operador Maior ou Igual a

#ENTRADAS DO PROGRAMA
X = float(input("Digite X:"))
Y = float(input("Digite Y:"))
#PROCESSAMENTO
if(X>=Y):
#SAÍDA
  print("X é Maior ou Igual a Y.")

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# #**Exemplo 04** [Acessar Fluxograma](https://github.com/igarashimassaki/LinguagemPython/blob/main/LP02_INTRODU%C3%87%C3%83O_%C3%80_LINGUAGEM_DE_PROGRAMA%C3%87%C3%83O_PYTHON%20-%20Exemplo03.pdf)
# Crie um código de programa em linguagem Python para Solicitar dois valores de nota p1 e p2 e em seguida calcular e exibir o resultado da média destas notas.

# %%
#ENTRADAS DO PROGRAMA
p1 = float(input("Digite nota p1:"))
p2 = float(input("Digite nota p2:"))
#PROCESSAMENTO
m = (p1+p2)/2.
#SAÍDA NA TELA
print("Média = " + str(m))

# %% [markdown]
#   ![LP03 - Tipos de Dados.png](data:image/png;base64,...)

# %%
#int -> tipo inteiro
x = 2 #A variável x reconhece automaticamente o número inteiro 2 e assume seu tipo como inteiro
y = 3 #A variável y reconhece automaticamente o número inteiro 3 e assume seu tipo como inteiro
soma = x + y #Ao realizar a soma das variáveis x + y a variável soma herda, automaticamente, o tipo inteiro de dados
type(soma) #A função type faz exibir na tela o tipo de dados da variável ou obeto nela contido

# %%
#float -> tipo ponto flutuante
x = 2.5 #A variável x reconhece automaticamente o número inteiro 2 e assume seu tipo como inteiro
y = 3 #A variável y reconhece automaticamente o número inteiro 3 e assume seu tipo como inteiro
soma = (x + y)/2.0 #Ao realizar a média aritmética das variáveis x e y a variável soma herda, automaticamente, o tipo decimal de dados, já que precisa dividir por 2.0
type(soma) #A função type faz exibir na tela o tipo de dados da variável ou obeto nela contido

# %%
#str -> tipo caracter
x = "2" #A variável x reconhece automaticamente o caracter 2 e assume seu tipo como String, pois o número 2 vem entre ASPAS
y = "3" #A variável x reconhece automaticamente o caracter 3 e assume seu tipo como String, pois o número 3 vem entre ASPAS
JOINT = x + y #Ao realizar a soma das variáveis x + y TIPO strings, a variável JOINT herda, automaticamente, o tipo STRING de dados
type(JOINT) #A função type faz exibir na tela o tipo de dados da variável ou obeto nela contido

# %%
#bool -> tipo booleano
resp = 2<3
type(resp)

# %%
resp = 2<3
print(resp)

# %% [markdown]
# #**EXERCÍCIOS**

# %% [markdown]
# ## **Ex.05)Após ter criado em aula a narrativa, o pseudocódigo e o fluxograma; agora é pedido que faça um programa em linguagem Python para receber do usuário um raio(r) de uma esfera, e em seguida calcular e exibir o seu volume(v) desta esfera:**

# %%
PI = 3.14159265358979323846
r = float(input("Digite o raio r da esfera: "))
v = (4/3.0)*PI*r*r
print("Volume v = ", v)

# %% [markdown]
# ## **Ex.06)Após ter criado em aula a narrativa, o pseudocódigo e o fluxograma; agora é pedido que faça um programa em linguagem Python para receber do usuário um ângulo em Graus(g), e em seguida calcular e exibir o valor correspondente em radianos:**

# %%
PI = 3.14159265358979323846
g = float(input("Digite o ângulo em graus: "))
v = g*PI/180.0
print("Volume v = ", v)

# %% [markdown]
# ## **Ex.07)Após ter criado em aula a narrativa, o pseudocódigo e o fluxograma; agora é pedido que faça um programa em linguagem Python para receber do usuário um ângulo em Radianos(rad), e em seguida calcular e exibir o valor correspondente em Graus(g):**

# %%
PI = 3.14159265358979323846
rad = float(input("Digite o ângulo em Radianos: "))
g = rad*180.0/PI
print("Valor convertido em graus = ", g)

# %% [markdown]
# ## **Ex.08)Após ter criado em aula a narrativa, o pseudocódigo e o fluxograma; agora é pedido que faça um programa em linguagem Python para receber do usuário um ângulo em Radianos(rad), e em seguida calcular e exibir o valor correspondente em Grados(Gr).** OBS: Lembrar que 400grados=2PI

# %%
PI = 3.14159265358979323846
rad = float(input("Digite o ângulo em Radianos: "))
Gr = (400*rad)/(2*PI)
print("Valor convertido em graus = ", Gr)

# %% [markdown]
# #**Referências Bibliográficas**
# [01](https://www.ibm.com/topics/software-development)
#
# [02](https://www.freecodecamp.org/portuguese/news/linguagens-de-programacao-interpretadas-x-compiladas-qual-e-a-diferenca/)
#
# [03](https://www.w3schools.com/git/git_intro.asp?remote=github)
